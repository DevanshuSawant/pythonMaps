# %% [markdown]
# ## Read raw data from csv file

# %%
import numpy as np
import pandas as pd

valid_routes = ["2","6","8","9","10","12","13","16","20","23","27","34","36","39","40","43","46","51","52","52B","53","54","56","56A","59","60","61","62","63","65","69","70","75","78","82","85","87","88","89","91","92","93","94","95","96","98","102","104","110","111","112","115","122","126"]
stops = pd.read_csv("TMTStopsThroughRoutes(5).csv")
stops.head()

new = stops["route_num"].isin(valid_routes)
stops = stops[new].drop_duplicates()

# %% [markdown]
# ## We need to take the following steps to get the data into a format that we can use for our analysis:
# 1. Find unique stop names-
#   - remove exact duplicates.
# 2. Merge the duplicates into one stop name

# %% [markdown]
# ### Compile all Bus Stops in Direction 0:

# %%
names_dir_0 = stops.loc[stops["route_direction"]==0, "name" ].str.lower().unique()
names_dir_0.sort()
print(names_dir_0)
# Out:
# ['a k joshi' 'a.k. joshi vidyalaya' 'aai mata mandir'
#  'aai mata mandir chowk' 'aalimghar' 'aashapura mndir' 'aban park'
#  'abhiruchi' 'abhiruchi / castle mill' 'abhiruchi / holly cross school'
#  'achole talav' 'agarwal estate' 'agriculture' 'air force station'
#  'air force station kolshet' 'almos colony' 'amar palace' 'ambaji dham'
#  'ambika nagar' 'ambika yog kutir' 'ambika yoga kutir' 'ambika yogkutir'
#  'amrut angan' 'amrut nagar' 'anand nagar' 'anand nagar depot'
#  'anand vihar' 'anjur' 'anjur phata' 'anunagar' 'aradhana cinema'
#  'ashapura mandir' 'ashapura mandir / majiwada naka' 'ashok nagar'
#  'asian cable' 'atriya society' 'automatic company' 'azad nagar'
#  'azad nagar naka' 'babla compound / hanuman mandir' 'balkum naka'
#  'balkum pada no 1' 'balkum pada no 2' 'balkum pada no 3' 'bapana bridge'
#  'bappa sitaram' 'bara bunglow' 'batata company'
#  'batata company / vijay garden' 'batata company / vijay garden / dmart'
#  'bayer main gate' 'bethany hospital' 'bhaindar pada'
#  'bhandup pumping centre' 'bharat gears' 'bharat nagar' 'bhendi pada'
#  'bhiwandi bypass' 'bhiwandi st bus stand' 'bhoidapada' 'bhoomi acres'
#  'bhoomi world' 'bhu kendra' 'bkc' 'boringer' 'borivali station (east)'
#  'borivali sukurwadi st bus stop' 'bradma compound' 'brahmand'
#  'brahmand phase 1,2' 'brahmand phase 2' 'brahmand phase 4'
#  'brahmand phase 5' 'brahmand phase 6' 'bramhala talav / manorpada'
#  'bramhla talav/ mnorpada' 'building no 3' 'building no. 3'
#  'cadbury company' 'cadbury juction' 'cadbury junction'
#  'cadbury junction 2' 'castel mil' 'castle mill' 'castle mill / abhiruchi'
#  'central maidan' 'central park nalasopara' 'chamunda' 'chandan naka'
#  'chena bridge' 'chendani koliwada' 'chendani koliwada (cidco)'
#  'chhabhaiya park' 'chhatrapati shivaji maharaj chowk bhiwandi'
#  'chheda nagar' 'chinchoti naka' 'chintamani hotel / jain temple'
#  'citi bank bkc' 'civil hospital' 'colour chem' 'cosmos paradise'
#  'court naka' 'dadlani park' 'dadoji konddev stadium' 'dahisar check naka'
#  'dahisar toll naka' 'damyanti smruti' 'datta mandir' 'datta wadi'
#  'dattu wadi mumbra/sainath hospital' 'devdaya nagar'
#  'dharamvir nagar / happy valley circle' 'dharmveer ngar / happy valley'
#  'dhokali naka' 'diamond market bkc' 'diva' 'diva 1 / diva gaon / anjur'
#  'diva 2 / diva phata / petrol pump' 'diva phata'
#  'diva-vasai railway bridge' 'diwale/bhandarli gaon' 'dnyan sarita'
#  'dnyan sarita college' 'dnyaneshwar nagar' 'dnyansadhna college'
#  'dongri pada' 'durdwani kendra' 'durgesh complex' 'durgesh park'
#  'dwarka hotel' 'edenwood' 'everest world park' 'evershine city' 'exotica'
#  'family court bkc' 'father wadi' 'fire station' 'flower valley'
#  'flower valley / jupiter hospital' 'forest avenue' 'forest office'
#  'fountain hotel' 'gaimukh' 'gaimukh mandir / jagannath mahadev temple'
#  'gandhi nagar' 'ganesh nagar' 'gaondevi' 'gaondevi mandir kopri'
#  'garden est.' 'garden estate' 'garib nagar' 'gavdevi mandir thane (w)'
#  'gawand baug' 'ghartan pada' 'ghodbunder village' 'gholai nagar'
#  'godrej soaps' 'gokhivare talav vasai' 'gokul anand hotel borivali east'
#  'gokul nagar' 'gokulngar' 'golden chemicals' 'gondhale wadi'
#  'gopal nagar' 'gurukul society' 'gyan sarita' 'gyan sarita sada'
#  'gyaneshvar nagar' 'gynan sadhana college' 'gynansadhana college'
#  'hanuman complex' 'hari nivas' 'hari niwas' 'harinivas' 'hatkesh'
#  'havre city / borivade gaon' 'highland park' 'highway darshan'
#  'highway darshan society' 'hill garden' 'hiranandani'
#  'hiranandani meadows' 'hirandani garden' 'holly cross school'
#  'holy cross school' 'holy mary high school' 'hyde park' 'ice factory'
#  'icici bank bkc' 'imperial square' 'income tax office' 'indira nagar'
#  'iti circle' 'iti thane' 'j k gram' 'jablinaka'
#  'jagannath mahadev temple' 'jai bhawani nagar' 'jakat naka'
#  'jambhali naka' 'jambli naka' 'jangid circle' 'jawahar nagar'
#  'johnson company' 'jupiter hospital' 'jyotiba phule nagar / sukur park'
#  'kajupada' 'kajuwadi' 'kaka nagar' 'kalher' 'kalher pipe line'
#  'kalpataru' 'kalsekar college' 'kalsekar college / k.v.k.' 'kalwa depot'
#  'kalwa naka' 'kalwa railway station' 'kalyan bypass' 'kalyan phata'
#  'kamagar hospital mulund' 'kamgar hospital' 'kamgar hospital mulund'
#  'kanhaji agrh chowk' 'kanjur marg village' 'kannamwar nagar'
#  'kapadia nagar' 'kapurbavdi' 'kapurbawdi' 'kasarvadavali'
#  'kasarvadavali / sainik shala' 'kasarvadavali naka' 'kasheli'
#  'kasheli gaon' 'kasheli toll naka' 'kashi village' 'kashimira'
#  'kashish park' 'kausa' 'kausa jama masjid'
#  'kavyadhara / siddheshwar garden' 'khalsekar' 'khandagale estate'
#  'khandelwal' 'khandelwal estate' 'kharegaon' 'kharegaon fatak'
#  'kharegaon naka' 'kharegaon pakhadi' 'khevra cercal' 'khewra circle'
#  'khidkali temple' 'khirkali' 'khopat' 'khopat s.t. workshop'
#  'kinara dhaba' 'kisan nagar' 'kismat colony' 'kms / n g regency'
#  'kokanipada' 'koknipada' 'kolbad' 'kolshet gaon' 'kolshet trichapada'
#  'kopar' 'koras company' 'kores nakshtra' 'kousa gaon' 'kousa jama masjid'
#  'lakshmi narayan residency' 'lalit clinic' 'laxmi industry'
#  'laxmi narayan society' 'laxmi park' 'leonard' 'little angel school'
#  'lockim / r mall' 'lockim company' 'lockim company / r mall' 'lodha'
#  'lodha / saket' 'lodha complex' 'lodha dham' 'lodha gate' 'lok puram'
#  'lokim company / r mall' 'lokim company/ r mall' 'lokmanya nagar'
#  'louiswadi' 'm. i. d. c' 'm.i.d.c' 'm.i.d.c.' 'mahagiri koliwada'
#  'mahapalika bhavan' 'mahapalika bhawan' 'maharashtra nagar'
#  'mahavishnu mandir samrat' 'majiwada' 'majiwada gaon'
#  'majiwada gaon corner' 'majiwada naka' 'makhamali talav' 'malhar cinema'
#  'manisha nagar' 'mankoli' 'mankoli naka' 'manorama nagar' 'manpada'
#  'maratha punjab / madvi chowk' 'mhada vasahat' 'mhatre wadi / patil wadi'
#  'millenium hospital / shimla park' 'mini punjab' 'mira gaon'
#  'mira gaothan' 'mira road station' 'mithagar' 'mkhamali talav'
#  'mohammad estate' 'monalisa lawns' 'mtnl' 'mtnl telephone exchange bkc'
#  'muchhala college' 'muktai nagar' 'muktaingar' 'mulla bagh'
#  'mulund check naka' 'mulund check naka (narpoli)' 'mulund shivsena'
#  'mulund sonapur' 'mulund station (w)' 'mumbra' 'mumbra police station'
#  'mumbra prabhat office' 'mumbra railway station' 'mumbra shiv mandir'
#  'mumbra toll naka' 'municipal commissioner house' 'murfi company'
#  'nadanawan homes' 'nalanda' 'nalasopara railway station (e)'
#  'namdev wadi' 'narpoli police station' 'nashimat colony' 'nency colony'
#  'new shakti mill' 'new shakti mill / ambedkar road' 'nitin company'
#  'novartis' 'omkareshwar mandir' 'oriental bank' 'oswal park'
#  'oswal sagar hall' 'ovala' 'ovala gaon' 'owali'
#  'pach rasta devidayal road' 'padle gaon' 'panchamrit' 'paras shop'
#  'parkwood society' 'parmarth niketan' 'parsik nagar' 'passport office'
#  'passport office / m.i.d.c' 'pathar pada' 'patli pada' 'pawar nagar'
#  'pimplas' 'pipe line' 'pipe line kalher' 'pipeline road'
#  'piyushpani parshvanath jain temple' 'police line' 'poshmata mandir'
#  'power house' 'prabhat cinema' 'pradeep society' 'prem nagar'
#  'pudhari nagar' 'pujani estate' 'purna' 'r. t. o/ central jail'
#  'r.t.o thane' 'r.t.o. / kamraj nagar' 'rabodi' 'raghukul society'
#  'rahnal' 'raj park' 'ram mandir' 'ramabai nagar' 'ramchandra nagar'
#  'ramchandra nagar no 1' 'rameshwar society' 'range office' 'raval pada'
#  'ravi fisheries' 'raymond' 'reliance market'
#  'reserve bank of india (rbi) bkc' 'reti bunder 1'
#  'reti bunder 2/ranna nagar' 'reti bunder 3' 'reti bunder circle'
#  'retibunder 2' 'retibunder 3' 'retibunder number 1'
#  'retibunder number 2/ranna nagar' 'retibunder number 3' 'retuibunder 1'
#  'road no 16' 'road no 22' 'road no 27' 'royal garden resort'
#  'runwal garden city' 'runwal plaza' 'rutu tower'
#  's t juna thamba / shastri nagar' 's t juna thamba / shastri nagar naka'
#  'sachin society' 'sahakar nagar' 'sahayog soc' 'sahayog society'
#  'sahyadri society' 'sai nath nagar' 'saibaba mandir' 'sainath nagar'
#  'saket complex' 'sambhaji hotel' 'sambhaji nagar'
#  'samrat hotel / mahavishnu mandir' 'sandoz baug'
#  'sanjay nagar/shiv sena office' 'santoshi mata mandir'
#  'santoshi mata temple' 'sasunavghar' 'sathe nagar' 'sativali naka'
#  'sativali phata' 'sativali phata bus station / gavri devi temple'
#  'savarkar nagar naka' 'sawarkar nagar' 'school no 7'
#  'shahu maharaj market' 'shashkiy vishram gruh versova, ghodbunder'
#  'shaskiya niwas kopri' 'shastri nagar' 'shastri nagar naka'
#  'shibli nagar' 'shil phata' 'shiv sena shakha mulund' 'shivai nagar'
#  'shree maa bal niketan' 'shree ram nagar' 'shri ram hospital'
#  'shrirang society' 'shruti park' 'siddharth nagar shashkiya niwas'
#  'siddhivinayak tower' 'sidheswar talav' 'silver park' 'st work shop'
#  'st. xavier school' 'st. xaviers school' 'standford society'
#  'subhash nagar' 'subhash tower' 'sukur park' 'surai phata'
#  'swami vivekanand chowk' 'swarvali devi' 'swastik park' 'swastik regalia'
#  'swayam siddhi college' 'talao pali' 'tanwar nagar' 'tata motors'
#  'tattvagyan vidyapeeth' 'teen hath naka' 'tembhi naka'
#  'thane station (east) kopri' 'thane station west satis' 'tikuji ni wadi'
#  'tikujiniwadi' 'tirupati' 'trimurti school' 'tukaram niwas' 'tulshidham'
#  'umrao' 'upavan talav' 'upvan talav' 'uthalsar' 'vadvali naka'
#  'vaiti wadi' 'valiv phata' 'vandana cinema' 'vandna cinema'
#  'vanjarpatti flyover' 'vardhman garden' 'varsova / fountain hotel'
#  'vartak nagar' 'vartak nagar naka' 'vasant leela' 'vasant nagari'
#  'vasant vihar' 'vasant vihar phata' 'vastu anand'
#  'vedant hospital garib nagar' 'vehele panchayat' 'vidyapith'
#  'vijay garden' 'vijay nagari' 'vikhroli police station'
#  'vikhroli station road' 'vilas park' 'vimal nagar' 'vivekanand nagar'
#  'voltas gate' 'vrindavan society' 'wagh bill naka' 'waghbil gaon'
#  'wagle agar' 'wagle bus depot' 'wagle circle' 'wellman company'
#  'western hotel' 'western hotel / lakshmi baug' 'yashaswi nagar'
#  'yashaswi nagar pipeline' 'yashodhan nagar' 'yashwant pada'
#  'yeoor / patonapada' 'yeoor gaon']

# %%
import folium
import random
import geopandas as gpd

map = folium.Map(location=[19.2, 72.9], tiles="OpenStreetMap", zoom_start=12)
    
i=0
p=0
stops_refined_dir_0 =[]
check_names = []
colors = ['gray', 'white', 'orange', 'pink', 'black', 'blue', 'darkgreen', 'darkred', 'darkpurple', 'lightblue', 'lightgray', 'green', 'lightred', 'darkblue', 'red', 'purple', 'beige', 'cadetblue', 'lightgreen']

for name in names_dir_0:
    stops_refined = stops.loc[stops["name"].str.lower()==name.lower(), ["name", "ref", "route_num", "route_direction", "longitude", "latitude", "position"]]
    stops_refined_1 = stops_refined.loc[stops_refined["route_direction"]==0, ["name", "ref", "route_num", "route_direction", "longitude", "latitude", "position"]]
    # print(stops_refined_1["properties/ref"])
    def range_of_coordinates(x):
        return max(x) - min(x)
    
    if (range_of_coordinates(stops_refined_1["latitude"])>0.002 or range_of_coordinates(stops_refined_1["longitude"])>0.002):
        # print(name, range_of_coordinates(stops_refined_1["latitude"]), range_of_coordinates(stops_refined_1["longitude"]))
        check_names.append(name)
        rand_color_1 = random.choice(colors)
        for j in range(len(stops_refined_1)):
            # print(stops_refined_1['properties/name'].iloc[0])
            folium.Marker([stops_refined_1['latitude'].iloc[j], stops_refined_1['longitude'].iloc[j]], popup=stops_refined_1['name'].iloc[j]+str(stops_refined_1['ref'].iloc[j]), icon=folium.Icon(color=rand_color_1)).add_to(map)
        p+=1
        
    else:
        avg_lat = stops_refined_1["latitude"].mean()
        avg_long = stops_refined_1["longitude"].mean()
        refs = ""
        for item in stops_refined_1["ref"].sort_values():
            refs += str(item) + ","

        route_nums = ""
        for item in stops_refined_1["route_num"].sort_values():
            route_nums += str(item) + ","
            
        name = stops_refined_1['name'].iloc[0]

        stops_refined_dir_0.append([name, refs, route_nums, avg_lat, avg_long])
    # stops_refined_2 = stops_refined_2.append(stops_refined_2, refs)
    i+=1
# print(stops_refined_dir_1)
stops_refined_dir_0 = pd.DataFrame(stops_refined_dir_0, columns=["name", "refs", "route_nums", "avg_lat", "avg_long"])
stops_direction_0_gdf = gpd.GeoDataFrame(stops_refined_dir_0, columns=["name", "refs", "route_nums"], geometry=gpd.points_from_xy(stops_refined_dir_0['avg_long'], stops_refined_dir_0['avg_lat']))  # type: ignore
stops_direction_0_gdf.to_file("stops_direction_0.geojson", driver='GeoJSON')

# %% [markdown]
# ### Compile all Bus Stops in Direction 1:

# %%
names_dir_1 = stops.loc[stops["route_direction"]==1, "name" ].str.lower().unique()
names_dir_1.sort()
names_dir_1
print(stops.loc[stops["route_direction"]==1, "name" ])
# Out:
# 65            Wagle Agar
# 66           Sathe Nagar
# 67       Passport Office
# 68             ITI Thane
# 69            Road No 27
#               ...
# 4111    Brahmand Phase 4
# 4112        Swastik Park
# 4113    Brahmand Phase 5
# 4114    Brahmand Phase 6
# 4115            Brahmand
# Name: name, Length: 1388, dtype: object

# %% [markdown]
# ## Check Directions

# %%
import folium
import random
import geopandas as gpd

map = folium.Map(location=[19.2, 72.9], tiles="OpenStreetMap", zoom_start=12)
    
i=0
p=0
stops_refined_dir_1 =[]
check_names = []
colors = ['gray', 'white', 'orange', 'pink', 'black', 'blue', 'darkgreen', 'darkred', 'darkpurple', 'lightblue', 'lightgray', 'green', 'lightred', 'darkblue', 'red', 'purple', 'beige', 'cadetblue', 'lightgreen']

for name in names_dir_1:
    stops_refined = stops.loc[stops["name"].str.lower()==name.lower(), ["name", "ref", "route_num", "route_direction", "longitude", "latitude", "position"]]
    stops_refined_1 = stops_refined.loc[stops_refined["route_direction"]==1, ["name", "ref", "route_num", "route_direction", "longitude", "latitude", "position"]]
    # print(stops_refined_1["properties/ref"])
    def range_of_coordinates(x):
        return max(x) - min(x)
    
    if (range_of_coordinates(stops_refined_1["latitude"])>0.002 or range_of_coordinates(stops_refined_1["longitude"])>0.002):
        # print(name, range_of_coordinates(stops_refined_1["latitude"]), range_of_coordinates(stops_refined_1["longitude"]))
        check_names.append(name)
        rand_color_1 = random.choice(colors)
        for j in range(len(stops_refined_1)):
            # print(stops_refined_1['properties/name'].iloc[0])
            folium.Marker([stops_refined_1['latitude'].iloc[j], stops_refined_1['longitude'].iloc[j]], popup=stops_refined_1['name'].iloc[j]+str(stops_refined_1['ref'].iloc[j]), icon=folium.Icon(color=rand_color_1)).add_to(map)
        p+=1
        
    else:
        avg_lat = stops_refined_1["latitude"].mean()
        avg_long = stops_refined_1["longitude"].mean()
        refs = ""
        for item in stops_refined_1["ref"].sort_values():
            refs += str(item) + ","

        route_nums = ""
        for item in stops_refined_1["route_num"].sort_values():
            route_nums += str(item) + ","
            
        name = stops_refined_1['name'].iloc[0]

        stops_refined_dir_1.append([name, refs, route_nums, avg_lat, avg_long])
    # stops_refined_2 = stops_refined_2.append(stops_refined_2, refs)
    i+=1
# print(stops_refined_dir_1)
stops_refined_dir_1 = pd.DataFrame(stops_refined_dir_1, columns=["name", "refs", "route_nums", "avg_lat", "avg_long"])
stops_direction_1_gdf = gpd.GeoDataFrame(stops_refined_dir_1, columns=["name", "refs", "route_nums"], geometry=gpd.points_from_xy(stops_refined_dir_1['avg_long'], stops_refined_dir_1['avg_lat']))  # type: ignore
stops_direction_1_gdf.to_file("stops_direction_1.geojson", driver='GeoJSON')

# %%
import folium
import random

map = folium.Map(location=[19.2, 72.9], tiles="OpenStreetMap", zoom_start=12)
colors = ['gray', 'white', 'orange', 'pink', 'black', 'blue', 'darkgreen', 'darkred', 'darkpurple', 'lightblue', 'lightgray', 'green', 'lightred', 'darkblue', 'red', 'purple', 'beige', 'cadetblue', 'lightgreen']

for i in range(len(valid_routes)):
    rand_color_1 = random.choice(colors)
    stop_for_valid_routes = stops.loc[stops["route_num"]==valid_routes[i], ["route_direction", "name", "ref", "route_num", "longitude", "latitude", "position"]]
    stop_for_valid_routes_1 = stop_for_valid_routes.loc[stop_for_valid_routes["route_direction"]==1, [ "name", "ref", "route_num", "longitude", "latitude", "position"]]
    stop_for_valid_routes_2 = stop_for_valid_routes_1.loc[stop_for_valid_routes_1["position"]==1, [ "name", "ref", "route_num", "longitude", "latitude"]]
    for j in range(len(stop_for_valid_routes_2['latitude'])):
        x=len(stop_for_valid_routes_1)-1
        folium.Marker([stop_for_valid_routes_2['latitude'].iloc[j], stop_for_valid_routes_2['longitude'].iloc[j]], popup=stop_for_valid_routes_2['route_num'].iloc[j]+str(stop_for_valid_routes_2['ref'].iloc[j]), icon=folium.Icon(color="green")).add_to(map)
        folium.Marker([stop_for_valid_routes_1['latitude'].iloc[x], stop_for_valid_routes_1['longitude'].iloc[x]], popup=stop_for_valid_routes_1['route_num'].iloc[x]+str(stop_for_valid_routes_1['ref'].iloc[x]), icon=folium.Icon(color="red")).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c65085d0e652a9357b15078e8b471928 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c65085d0e652a9357b15078e8b471928&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c65085d0e652a9357b15078e8b471928 = L.map(
#                 &quot;map_c65085d0e652a9357b15078e8b471928&quot;,
#                 {
#                     center: [19.2, 72.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_209e48e710eaf4fcef8458be99ea26fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c65085d0e652a9357b15078e8b471928);
#
#
#             var marker_83fef313769fc74d84c4957e611863b6 = L.marker(
#                 [19.1871381, 72.9772101],
#                 {}
#             ).addTo(map_c65085d0e652a9357b15078e8b471928);
#
#
#             var icon_34b2484889bf7a9bbe769c4604cc9681 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83fef313769fc74d84c4957e611863b6.setIcon(icon_34b2484889bf7a9bbe769c4604cc9681);
#
#
#         var popup_5ffffc781982af9631c0b0060481ee3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fca09d1e09bb66740f6eb5c72357cbe1 = $(`&lt;div id=&quot;html_fca09d1e09bb66740f6eb5c72357cbe1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;22962&lt;/div&gt;`)[0];
#                 popup_5ffffc781982af9631c0b0060481ee3a.setContent(html_fca09d1e09bb66740f6eb5c72357cbe1);
#
#
#
#         marker_83fef313769fc74d84c4957e611863b6.bindPopup(popup_5ffffc781982af9631c0b0060481ee3a)
#         ;
#
#
#
#
#             var marker_904036af3cb95bc35e0e6f01b1f8a067 = L.marker(
#                 [19.2030599, 72.9799637],
#                 {}
#             ).addTo(map_c65085d0e652a9357b15078e8b471928);
#
#
#             var icon_f674fe010c2d06dcd3eec07d0e7c40b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_904036af3cb95bc35e0e6f01b1f8a067.setIcon(icon_f674fe010c2d06dcd3eec07d0e7c40b4);
#
#
#         var popup_054f91a39adbd92b8c8c373a1a9832e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ec21c895674aaa5cd56e2b134722a6a = $(`&lt;div id=&quot;html_0ec21c895674aaa5cd56e2b134722a6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;22968&lt;/div&gt;`)[0];
#                 popup_054f91a39adbd92b8c8c373a1a9832e4.setContent(html_0ec21c895674aaa5cd56e2b134722a6a);
#
#
#
#         marker_904036af3cb95bc35e0e6f01b1f8a067.bindPopup(popup_054f91a39adbd92b8c8c373a1a9832e4)
#         ;
#
#
#
#
#             var marker_612b8abe130c0c361c993ae84cd96ee3 = L.marker(
#                 [19.2015885, 72.9459266],
#                 {}
#             ).addTo(map_c65085d0e652a9357b15078e8b471928);
#
#
#             var icon_30607cb620622bc36ec578f67d7e69fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_612b8abe130c0c361c993ae84cd96ee3.setIcon(icon_30607cb620622bc36ec578f67d7e69fd);
#
#
#         var popup_d5fadf2bef07db74caa03f105ab7a3cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4db159c8e90bbc5e2758338cb60599d9 = $(`&lt;div id=&quot;html_4db159c8e90bbc5e2758338cb60599d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6154&lt;/div&gt;`)[0];
#                 popup_d5fadf2bef07db74caa03f105ab7a3cb.setContent(html_4db159c8e90bbc5e2758338cb60599d9);
#
#
#
#         marker_612b8abe130c0c361c993ae84cd96ee3.bindPopup(popup_d5fadf2bef07db74caa03f105ab7a3cb)
#         ;
#
#
#
#
#             var marker_321d82249b3aaab70b136974fb65928a = L.marker(
#                 [19.2084109, 72.9827563],
#                 {}
#             ).addTo(map_c65085d0e652a9357b15078e8b471928);
#
#
#             var icon_7b68b04c3d66f95309e11b8df324424e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconC

# %%
cross_routes = [91,43,36,78,82,126,75]

# %%
import geopandas as gpd
import folium
from folium.plugins import HeatMap
map = folium.Map(location=[19.2, 72.9], tiles="OpenStreetMap", zoom_start=12)
for i in range(0,len(stops_refined_dir_0)):
    folium.Marker([stops_refined_dir_0['avg_lat'][i], stops_refined_dir_0['avg_long'][i]], popup=stops_refined_dir_0['name'][i]+str(stops_refined_dir_0['route_nums'])).add_to(map)
    # HeatMap([[stops_refined_dir_0['avg_lat'][i], stops_refined_dir_0['avg_long'][i]]], radius=len(stops_refined_dir_0["route_nums"][i])).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e38ac94ca74566e9e2beec448f6f2c99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e38ac94ca74566e9e2beec448f6f2c99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e38ac94ca74566e9e2beec448f6f2c99 = L.map(
#                 &quot;map_e38ac94ca74566e9e2beec448f6f2c99&quot;,
#                 {
#                     center: [19.2, 72.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f83dcb9c668572a3058b760831ee5b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e38ac94ca74566e9e2beec448f6f2c99);
#
#
#             var marker_00a95d181e982d22c5f7282d097a54f2 = L.marker(
#                 [19.1876851, 72.9717434],
#                 {}
#             ).addTo(map_e38ac94ca74566e9e2beec448f6f2c99);
#
#
#         var popup_765ffe15539ae946fd488cf49234cb30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15e26d28de18ad6f1a785eb57e6ed53a = $(`&lt;div id=&quot;html_15e26d28de18ad6f1a785eb57e6ed53a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A K Joshi0                                       56A, 1      20,23,34,36,43,52,53,6,78,8,91,95,96, 2                                       110, 3                                   115,122, 4                                        87,                        ...                   499                                   96,98, 500                   102,110,115,122,23,36, 501                                      69, 502                                      16, 503                                      16, Name: route_nums, Length: 504, dtype: object&lt;/div&gt;`)[0];
#                 popup_765ffe15539ae946fd488cf49234cb30.setContent(html_15e26d28de18ad6f1a785eb57e6ed53a);
#
#
#
#         marker_00a95d181e982d22c5f7282d097a54f2.bindPopup(popup_765ffe15539ae946fd488cf49234cb30)
#         ;
#
#
#
#
#             var marker_a8f6acdfd3362c7e1c666054d5715c89 = L.marker(
#                 [19.187638369230772, 72.9716968153846],
#                 {}
#             ).addTo(map_e38ac94ca74566e9e2beec448f6f2c99);
#
#
#         var popup_af3d2682d4c0ab6ff9219feb2b993c86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c590d38c806f72c0edfeb239851b5da4 = $(`&lt;div id=&quot;html_c590d38c806f72c0edfeb239851b5da4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A.K. Joshi Vidyalaya0                                       56A, 1      20,23,34,36,43,52,53,6,78,8,91,95,96, 2                                       110, 3                                   115,122, 4                                        87,                        ...                   499                                   96,98, 500                   102,110,115,122,23,36, 501                                      69, 502                                      16, 503                                      16, Name: route_nums, Length: 504, dtype: object&lt;/div&gt;`)[0];
#                 popup_af3d2682d4c0ab6ff9219feb2b993c86.setContent(html_c590d38c806f72c0edfeb239851b5da4);
#
#
#
#         marker_a8f6acdfd3362c7e1c666054d5715c89.bindPopup(popup_af3d2682d4c0ab6ff9219feb2b993c86)
#         ;
#
#
#
#
#             var marker_68f10d8153415e57cc2d0a5d6f9f497c = L.marker(
#                 [19.2070135, 72.9569281],
#                 {}
#             ).addTo(map_e38ac94ca74566e9e2beec448f6f2c99);
#
#
#         var popup_0b5d3a323e9628c482b6da192c838ce7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5ab198afb3735a99489874284a03f2d = $(`&lt;div id=&quot;html_d5ab198afb3735a99489874284a03f2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aai Mata Mandir0                                       56A, 1      20,23,34,36,43,52,53,6,78,8,91,95,96, 2                                       110, 3                                   115,122, 4                                        87,                        ...                   499                                   96,98, 500                   102,110,115,122,23,36, 501                                      69, 502                                      16, 503                                      16, Name: route_nums, Length: 504, dtype: object&lt;/div&gt;`)[0];
#                 popup_0b5d3a323e9628c482b6da192c838ce7.setContent(html_d5ab198afb3735a99489874284a03f2d);
#
#
#
#         marker_68f10d8153415e57cc2d0a5d6f9f497c.bindPopup(popup_0b5d3a323e9628c482b6da192c838ce7)
#         ;
#
#
#
#
#             var marker_af073997275531f2b5c0fdd5b8f97ec9 = L.marker(

# %%
import folium
from folium.plugins import HeatMap
map = folium.Map(location=[19.2, 72.9], tiles="OpenStreetMap", zoom_start=12)
for i in range(0,len(stops_refined_dir_1)):
    folium.Marker([stops_refined_dir_1['avg_lat'][i], stops_refined_dir_1['avg_long'][i]], popup=str(stops_refined_dir_1['route_nums'][i])).add_to(map)
    # HeatMap([[stops_refined_dir_0['avg_lat'][i], stops_refined_dir_0['avg_long'][i]]], radius=len(stops_refined_dir_0["route_nums"][i])).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e0dcdfaa7d306523c864e203cec250c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e0dcdfaa7d306523c864e203cec250c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e0dcdfaa7d306523c864e203cec250c = L.map(
#                 &quot;map_7e0dcdfaa7d306523c864e203cec250c&quot;,
#                 {
#                     center: [19.2, 72.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_246a0723f55bfb72b358c6c3557c822e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e0dcdfaa7d306523c864e203cec250c);
#
#
#             var marker_ffef4d0764eb85d37047b4447c932036 = L.marker(
#                 [19.1876087, 72.9717258],
#                 {}
#             ).addTo(map_7e0dcdfaa7d306523c864e203cec250c);
#
#
#         var popup_72bdc7c9dce36ee374c6887367563ceb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7371a7921bd4f0c7e2e7cd8915b4280c = $(`&lt;div id=&quot;html_7371a7921bd4f0c7e2e7cd8915b4280c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;56A,&lt;/div&gt;`)[0];
#                 popup_72bdc7c9dce36ee374c6887367563ceb.setContent(html_7371a7921bd4f0c7e2e7cd8915b4280c);
#
#
#
#         marker_ffef4d0764eb85d37047b4447c932036.bindPopup(popup_72bdc7c9dce36ee374c6887367563ceb)
#         ;
#
#
#
#
#             var marker_53feef5584721047c6180f63e7c5c3dd = L.marker(
#                 [19.187643758333333, 72.97178377499999],
#                 {}
#             ).addTo(map_7e0dcdfaa7d306523c864e203cec250c);
#
#
#         var popup_f046061d86261ab92050018e6ccb258e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c79103e42c65b6ee0757941f8e8ab58 = $(`&lt;div id=&quot;html_2c79103e42c65b6ee0757941f8e8ab58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20,23,34,36,43,52,53,6,78,8,91,95,&lt;/div&gt;`)[0];
#                 popup_f046061d86261ab92050018e6ccb258e.setContent(html_2c79103e42c65b6ee0757941f8e8ab58);
#
#
#
#         marker_53feef5584721047c6180f63e7c5c3dd.bindPopup(popup_f046061d86261ab92050018e6ccb258e)
#         ;
#
#
#
#
#             var marker_5d3c241808e2597d9e92a49d7809f8e6 = L.marker(
#                 [19.3976279, 72.8356342],
#                 {}
#             ).addTo(map_7e0dcdfaa7d306523c864e203cec250c);
#
#
#         var popup_da06497fb3985e73b670b5497cf0f665 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_524c463fe54738077e04b832cbb7c5ac = $(`&lt;div id=&quot;html_524c463fe54738077e04b832cbb7c5ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;69,&lt;/div&gt;`)[0];
#                 popup_da06497fb3985e73b670b5497cf0f665.setContent(html_524c463fe54738077e04b832cbb7c5ac);
#
#
#
#         marker_5d3c241808e2597d9e92a49d7809f8e6.bindPopup(popup_da06497fb3985e73b670b5497cf0f665)
#         ;
#
#
#
#
#             var marker_5600fded008fad5c45bfec615163b90a = L.marker(
#                 [19.2071149, 72.9569332],
#                 {}
#             ).addTo(map_7e0dcdfaa7d306523c864e203cec250c);
#
#
#         var popup_f3bf0366d62dd4eff221b0d48168d493 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38caa90d3cd9909211b6f62804c72443 = $(`&lt;div id=&quot;html_38caa90d3cd9909211b6f62804c72443&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;110,&lt;/div&gt;`)[0];
#                 popup_f3bf0366d62dd4eff221b0d48168d493.setContent(html_38caa90d3cd9909211b6f62804c72443);
#
#
#
#         marker_5600fded008fad5c45bfec615163b90a.bindPopup(popup_f3bf0366d62dd4eff221b0d48168d493)
#         ;
#
#
#
#
#             var marker_45f950b50d35dc7ab3ef81afd9a65bcf = L.marker(
#                 [19.2071157, 72.95693265],
#                 {}
#             ).addTo(map_7e0dcdfaa7d306523c864e203cec250c);
#
#
#         var popup_4e0dff314f07ef9355b15a47167317c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a638ba8adddeebcd3731a0c4fd410fc5 = $(`&lt;div id=&quot;html_a638ba8adddeebcd3731a0c4fd410fc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;115,122,&lt;/div&gt;`)[0];
#                 popup_4e0dff314f07ef9355b15a47167317c3.setContent(html_a638ba8adddeebcd3731a0c4fd410fc5);
#
#
#
#         marker_45f950b50d35dc7ab3ef81afd9a65bcf.bindPopup(popup_4e0dff314f07ef9355b15a47167317c3)
#         ;
#
#
#
#
#             var marker_857e24fc49685e2cf49caafefaec28f6 = L.marker(
#                 [19.2037617, 73.0363245],

# %%
from thefuzz import fuzz
s1 = "kokanipada"
s2 = "koknipada"
print(fuzz.ratio(s1, s2))
# Out:
# 95

# %% [markdown]
# ### Bus Stops in Route x Direction y

# %%
import folium
import random

map = folium.Map(location=[19.2, 72.9], tiles="OpenStreetMap", zoom_start=12)
colors = ['gray', 'white', 'orange', 'pink', 'black', 'blue', 'darkgreen', 'darkred', 'darkpurple', 'lightblue', 'lightgray', 'green', 'lightred', 'darkblue', 'red', 'purple', 'beige', 'cadetblue', 'lightgreen']

for i in range(len(stops_refined_dir_1)):
    if stops_refined_dir_1['route_nums'][i]==91:
        
        for i in range(0,len(stops_refined_dir_1)):
            folium.Marker([stops_refined_dir_1['avg_lat'].iloc[i], stops_refined_dir_1['avg_long'].iloc[i]], popup=stops_refined_dir_1['name'].iloc[i]).add_to(map)
        # HeatMap([[stops_refined_dir_0['avg_lat'][i], stops_refined_dir_0['avg_long'][i]]], radius=len(stops_refined_dir_0["route_nums"][i])).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_410c8ab7c428a47d6c26e2d8cc6f4a31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_410c8ab7c428a47d6c26e2d8cc6f4a31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_410c8ab7c428a47d6c26e2d8cc6f4a31 = L.map(
#                 &quot;map_410c8ab7c428a47d6c26e2d8cc6f4a31&quot;,
#                 {
#                     center: [19.2, 72.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_690faa5b225bcb44da2f546b7e15b426 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_410c8ab7c428a47d6c26e2d8cc6f4a31);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
osm_data = gpd.read_file("export(4).geojson")

# %%
osm_data.explore()
osm_data=osm_data.to_crs(3857)
stops_direction_1_gdf=stops_direction_1_gdf.set_crs(3857)

# stops_direction_1_gdf.to_crs(epsg=4326, inplace=True)

# %%
conflated_data = osm_data.sjoin_nearest(stops_direction_1_gdf)
conflated_data.drop(columns=['name_right'], inplace=True)
conflated_data.drop(columns=['@timestamp'], inplace=True)

conflated_data.head()
# Out:
#                id             @id access addr:city addr:housenumber  \
# 0  node/246449135  node/246449135   None      None             None
# 1  node/246472067  node/246472067   None      None             None
# 2  node/317914119  node/317914119   None      None             None
# 3  node/321951464  node/321951464   None      None             None
# 4  node/334531543  node/334531543   None      None             None
#
#   addr:postcode addr:street alt_name alt_name:hi amenity  ... tactile_paving  \
# 0          None        None     None        None    None  ...           None
# 1          None        None     None        None    None  ...           None
# 2          None        None     None        None    None  ...           None
# 3          None        None     None        None    None  ...           None
# 4          None        None     None        None    None  ...           None
#
#   wheelchair @version @changeset          @user      @uid  \
# 0       None       12  120841821   mvineetmenon  11353264
# 1       None        8  127977249   mvineetmenon  11353264
# 2       None        6  126705094  Monumental610  12430590
# 3       None       11   81892173      Neena2309   4785024
# 4       None       14   81891980      Neena2309   4785024
#
#                           geometry index_right   refs route_nums
# 0  POINT (8118057.111 2160334.212)         200  1459,        88,
# 1  POINT (8118863.175 2159901.791)         200  1459,        88,
# 2  POINT (8123758.216 2177834.950)         200  1459,        88,
# 3  POINT (8153227.435 2173080.534)         200  1459,        88,
# 4  POINT (8152969.308 2174119.444)         200  1459,        88,
#
# [5 rows x 60 columns]
